# %%
import numpy as np
import pandas as pd
data = pd.read_csv(r"C:\Users\samya\OneDrive\Documents\EVS\newpls\CarPrice_Assignment.csv")

data_numeric = data.select_dtypes(include=[np.number])
data_numeric = data_numeric.dropna()

X = data_numeric.drop('price', axis=1) 
y = data_numeric['price'] 

X = X.values
y = y.values

X_mean = X.mean(axis=0)
X_std = X.std(axis=0)
X = (X - X_mean) / X_std

X = np.hstack((np.ones((X.shape[0], 1)), X))

theta = np.zeros(X.shape[1])
alpha = 0.01  # Learning rate
iterations = 1000

def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    return (1 / (2 * m)) * np.sum(np.square(predictions - y))


for _ in range(iterations):
    predictions = X.dot(theta)
    errors = predictions - y
    theta -= (alpha / len(y)) * (X.T.dot(errors))


print("Theta (parameters):", theta)

predicted_prices = X.dot(theta)
print("Predicted Prices:", predicted_prices)
# Out:
# Theta (parameters): [13276.13739857 -1141.28389253   315.68320194   440.25053076
#   -133.75902173   877.47490893   533.68702687  1150.20072367
#   3682.45468429    62.64618903  -984.77507079  1064.16603765
#   2196.55193857   796.77554195  -135.7473605    211.62550281]
# Predicted Prices: [15227.19461865 15207.90890931 18743.25395942 13691.00079567
#  17261.38173262 16185.57744301 19591.26494681 19815.56791779
#  21179.57446725 19086.86701864 15197.1955113  14669.67202112
#  17623.01933973 17725.52797055 19734.51029113 28324.57604366
#  28557.44291768 31015.12725719  1675.86182976  7613.95769883
#   7386.54025764  6897.82673408  6908.24027778  8975.34911779
#   7027.39441203  7056.82643876  7037.54072942  8993.92744202
#  12689.95801299 16745.8183493   4345.75602913  7347.0104397
#   6419.27343559  8116.60755026  8132.7529217   8454.49305311
#   9327.98055358 10417.07673334 10515.15647907 10618.38200385
#   9642.56589984 11679.94908862 10792.11031417  7891.08126259
#   7131.81496541  6935.91585485 12186.98876028 31035.21023435
#  31015.92452502 45880.92862729  6437.09699224  6634.7970194
#   6626.5835228   6612.18891338  6615.56873512  9138.33835526
#   9119.05264592  9110.83914933 12146.691922   11068.29811808
#  11244.35305278 11029.7266994  11205.78163411 13781.63044102
#  11200.42685366 16371.685239   14167.07687729 25172.44820041
#  26155.23239864 24788.49680529 26492.80022407 31459.59181421
#  29444.8381764  39349.1516336  38102.57273    20733.57208797
#   6604.87002653  6675.54477706  6789.12562063  7881.69281135
#  10939.02192927  9824.41979627 15893.67391637 16071.57781495
#  16063.36431836  9809.17049499  9878.46248759 10857.05772979
#  10329.53423961  6422.56211345  8631.90051018  6448.20952868
#   6473.21267031  6372.17031489  6463.42900476  6348.66254085
#   6469.14643706  6323.81523067  6579.38753437 10488.72018554
#  10420.71674014 22017.80042848 22631.0429356  21921.02214491
#  22009.82034342 24026.13279383 22107.80071694 14673.49511769
#  18838.99012499 15866.96842958 19899.34928902 17754.72489417
#  18883.6416278  18510.31101633 19944.00079183 14641.00378316
#  18806.49879046 18905.40418046  5117.43381487  7123.92102146
#   5175.9663157   5140.50316268  6277.7049752  10860.13428967
#  15052.77614967 19197.74742607 26356.66646529 26337.38075596
#  26415.53051875 35141.16243551 10156.96813963  9445.45225064
#  14551.26034667 14357.10442062 17534.58837536 14458.04288249
#  17905.78720561 17718.74586524  8177.67087363  7733.08913787
#   8476.63760077  9266.09530691  8636.62615661 10833.83289195
#   9781.59226776 11427.99524347  9364.15942846 11079.85692286
#  10032.62713639 11603.48688233  4699.82844421  4854.73301384
#   4780.08624079  5950.29119439  5882.32197041  7678.87915074
#   5511.79151393  5510.72147697  8207.55489594  8400.14422617
#   5605.09230997  5411.54943782  5432.12369436  5388.53924368
#   5446.75902354 10785.37795316 10843.59773302 12614.03409855
#  12585.89061902 12599.8215479  12863.98448476 12922.20426462
#  13699.83165527  7757.3913174  10703.25535121  7674.73626292
#   7874.39414845  7733.60031637 20414.1521205  20504.24459024
#  19435.33227596 18594.67323587  8612.18646328  8252.66268553
#   8580.25837225  8220.7345945   8340.95876571  8909.53761498
#   9839.38079249  8336.46088077  7172.96944128 13096.78299916
#   9418.11028074  9416.33153885 15373.61023149 16163.2320768
#  15365.17051429 16121.57572138 16152.02244472 16919.49986454
#  16496.18875308 18820.58270072 21305.29729801 18496.52998241
#  16653.4185954 ]
